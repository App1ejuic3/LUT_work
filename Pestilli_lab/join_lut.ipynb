# %%
import pandas as pd

# %%
# Load the CSVs
snomed_file = 'csvOutput/WMT_LUT_SNOMED_results.csv'  
uberon_file = 'csvOutput/WMT_LUT_UBERON_results.csv' 

snomed_df = pd.read_csv(snomed_file, sep=',')
uberon_df = pd.read_csv(uberon_file, sep=',')
snomed_df.columns = snomed_df.columns.str.strip()
uberon_df.columns = uberon_df.columns.str.strip()


# Inspect the first few rows to confirm loading

print("SNOMED columns:", snomed_df.columns.tolist())
print(snomed_df.head(3))
print("\nUBERON columns:", uberon_df.columns.tolist())
print(uberon_df.head(3))
# Out:
# SNOMED columns: ['Id', 'Label', 'Synonyms', 'Annotation: alternative label', 'Annotation: preferred label', 'Incoming: subClassOf', 'Outgoing: Subclass Of', 'Outgoing: hierarchicalAncestors', 'Outgoing: hierarchicalChildren', 'Outgoing: hierarchicalDescendants']
#                 Id                                          Label  Synonyms  \
# 0  SNOMED_62872008               Structure of anterior commissure       NaN
# 1  SNOMED_89202009  Structure of superior longitudinal fasciculus       NaN
# 2   SNOMED_9000002                  Cerebellar peduncle structure       NaN
#
#                        Annotation: alternative label  \
# 0                                Anterior commissure
# 1  Arcuate fasciculus ; Superior longitudinal fas...
# 2                                Cerebellar peduncle
#
#                      Annotation: preferred label  \
# 0               Structure of anterior commissure
# 1  Structure of superior longitudinal fasciculus
# 2                  Cerebellar peduncle structure
#
#                                 Incoming: subClassOf Outgoing: Subclass Of  \
# 0                         Entire anterior commissure   hierarchicalParents
# 1            Entire superior longitudinal fasciculus   hierarchicalParents
# 2  Inferior cerebellar peduncle structure ; Cereb...   hierarchicalParents
#
#   Outgoing: hierarchicalAncestors Outgoing: hierarchicalChildren  \
# 0           hierarchicalAncestors           hierarchicalChildren
# 1           hierarchicalAncestors           hierarchicalChildren
# 2           hierarchicalAncestors           hierarchicalChildren
#
#   Outgoing: hierarchicalDescendants
# 0           hierarchicalDescendants
# 1           hierarchicalDescendants
# 2           hierarchicalDescendants
#
# UBERON columns: ['Id', 'Label', 'Annotation: database_cross_reference', 'Annotation: depiction', 'Annotation: dubious for taxon', 'Annotation: editor note', 'Annotation: external_definition', 'Annotation: external_ontology_notes', 'Annotation: has_alternative_id', 'Annotation: homology_notes', 'Annotation: id', 'Annotation: never in taxon', 'Annotation: present in taxon', 'Annotation: taxon_notes', 'Definition', 'IRI', 'Incoming: BSPO 0000122', 'Incoming: BSPO 0000123', 'Incoming: RO 0002296', 'Incoming: RO 0002433', 'Incoming: adjacent to', 'Incoming: overlaps', 'Incoming: part of', 'Incoming: rdf-schema#subClassOf', 'Incoming: results in morphogenesis of', 'Outgoing: Subclass Of (Is A)', 'Outgoing: ancestors', 'Outgoing: children', 'Outgoing: contributes to morphology of', 'Outgoing: descendants', 'Outgoing: extends fibers into', 'Outgoing: has part', 'Outgoing: hierarchicalAncestors', 'Outgoing: hierarchicalChildren', 'Outgoing: hierarchicalDescendants', 'Outgoing: in taxon', 'Outgoing: overlaps', 'Outgoing: parents', 'Outgoing: part of', 'Synonyms']
#                Id                        Label  \
# 0  UBERON:0003961            cingulum of brain
# 1  UBERON:0000935          anterior commissure
# 2  UBERON:0034746  anterior thalamic radiation
#
#                 Annotation: database_cross_reference  \
# 0  BAMS:cg ; DHBA:10572 ; EMAPA:37828 ; FMA:26076...
# 1  BAMS:AC ; BAMS:AG ; BAMS:Ac ; BAMS:ac ; BIRNLE...
# 2           DHBA:12043 ; FMA:76976 ; neuronames:1726
#
#                                Annotation: depiction  \
# 0                                                NaN
# 1  http://upload.wikimedia.org/wikipedia/commons/...
# 2                                                NaN
#
#   Annotation: dubious for taxon Annotation: editor note  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
#
#   Annotation: external_definition Annotation: external_ontology_notes  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
#
#   Annotation: has_alternative_id  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
#
#                           Annotation: homology_notes  ...  \
# 0                                                NaN  ...
# 1  In all vertebrates the thin structure that con...  ...
# 2                                                NaN  ...
#
#   Outgoing: extends fibers into Outgoing: has part  \
# 0                           NaN                NaN
# 1                           NaN                NaN
# 2                           NaN                NaN
#
#   Outgoing: hierarchicalAncestors Outgoing: hierarchicalChildren  \
# 0           hierarchicalAncestors           hierarchicalChildren
# 1           hierarchicalAncestors           hierarchicalChildren
# 2           hierarchicalAncestors                            NaN
#
#   Outgoing: hierarchicalDescendants Outgoing: in taxon Outgoing: overlaps  \
# 0           hierarchicalDescendants                NaN                NaN
# 1           hierarchicalDescendants                NaN                NaN
# 2                               NaN                NaN                NaN
#
#   Outgoing: parents                                  Outgoing: part of  \
# 0           parents  http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FBFO_0...
# 1           parents                                                NaN
# 2           parents  http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FBFO_0...
#
#                                             Synonyms
# 0  cingulum ; cingulum bundle ; cingulum of telen...
# 1  anterior cerebral commissure ; commissura ante...
# 2  anterior radiation of thalamus ; anterior thal...
#
# [3 rows x 40 columns]

# %%
# Merge on 'Label' with a full outer join
merged_df = pd.merge(
    snomed_df,
    uberon_df,
    on='Label',
    how='outer',
    suffixes=('_snomed', '_uberon')
)

# Inspect the merged result
print("\nMerged DataFrame:")
print(merged_df.head(10))

# Save the merged CSV
merged_df.to_csv('merged_white_matter.csv', index=False, sep='\t')
print("\nMerged CSV saved as 'merged_white_matter.csv'")
# Out:
# Merged DataFrame:
#           Id_snomed                                     Label  \
# 0    SNOMED_9000002             Cerebellar peduncle structure
# 1   SNOMED_87463005                 Cerebral fornix structure
# 2   SNOMED_36159002               Cerebral peduncle structure
# 3   SNOMED_88442005                 Corpus callosum structure
# 4  SNOMED_279300007                          External capsule
# 5   SNOMED_85637007                Internal capsule structure
# 6   SNOMED_28390009  Medial longitudinal fasciculus structure
# 7    SNOMED_3960005                 Olfactory tract structure
# 8   SNOMED_62872008          Structure of anterior commissure
# 9   SNOMED_37035000            Structure of cerebral cingulum
#
#    Synonyms_snomed                      Annotation: alternative label  \
# 0              NaN                                Cerebellar peduncle
# 1              NaN                                             Fornix
# 2              NaN  Basis pedunculi ; Cerebral peduncle ; Crus cer...
# 3              NaN             CC - Corpus callosum ; Corpus callosum
# 4              NaN                      Structure of external capsule
# 5              NaN  IC - Internal capsule ; Internal capsule ; Int...
# 6              NaN  MLF-Medial longitudinal fasciculus ; Medial lo...
# 7              NaN                                    Olfactory tract
# 8              NaN                                Anterior commissure
# 9              NaN  Cingulate fasciculus ; Cingulum ; Structure of...
#
#                 Annotation: preferred label  \
# 0             Cerebellar peduncle structure
# 1                 Cerebral fornix structure
# 2               Cerebral peduncle structure
# 3                 Corpus callosum structure
# 4                          External capsule
# 5                Internal capsule structure
# 6  Medial longitudinal fasciculus structure
# 7                 Olfactory tract structure
# 8          Structure of anterior commissure
# 9            Structure of cerebral cingulum
#
#                                 Incoming: subClassOf Outgoing: Subclass Of  \
# 0  Inferior cerebellar peduncle structure ; Cereb...   hierarchicalParents
# 1  Structure of columns of fornix ; Structure of ...   hierarchicalParents
# 2  Structure of tegmentum of midbrain ; Entire ce...   hierarchicalParents
# 3      Corpus callosum part ; Entire corpus callosum   hierarchicalParents
# 4                            Entire external capsule   hierarchicalParents
# 5  Entire internal capsule ; Part of internal cap...   hierarchicalParents
# 6  Structure of pontine portion of medial longitu...   hierarchicalParents
# 7  Structure of olfactory trigone ; Entire olfact...   hierarchicalParents
# 8                         Entire anterior commissure   hierarchicalParents
# 9                           Entire cerebral cingulum   hierarchicalParents
#
#   Outgoing: hierarchicalAncestors_snomed  \
# 0                  hierarchicalAncestors
# 1                  hierarchicalAncestors
# 2                  hierarchicalAncestors
# 3                  hierarchicalAncestors
# 4                  hierarchicalAncestors
# 5                  hierarchicalAncestors
# 6                  hierarchicalAncestors
# 7                  hierarchicalAncestors
# 8                  hierarchicalAncestors
# 9                  hierarchicalAncestors
#
#   Outgoing: hierarchicalChildren_snomed  \
# 0                  hierarchicalChildren
# 1                  hierarchicalChildren
# 2                  hierarchicalChildren
# 3                  hierarchicalChildren
# 4                  hierarchicalChildren
# 5                  hierarchicalChildren
# 6                  hierarchicalChildren
# 7                  hierarchicalChildren
# 8                  hierarchicalChildren
# 9                  hierarchicalChildren
#
#   Outgoing: hierarchicalDescendants_snomed  ... Outgoing: extends fibers into  \
# 0                  hierarchicalDescendants  ...                           NaN
# 1                  hierarchicalDescendants  ...                           NaN
# 2                  hierarchicalDescendants  ...                           NaN
# 3                  hierarchicalDescendants  ...                           NaN
# 4                  hierarchicalDescendants  ...                           NaN
# 5                  hierarchicalDescendants  ...                           NaN
# 6                  hierarchicalDescendants  ...                           NaN
# 7                  hierarchicalDescendants  ...                           NaN
# 8                  hierarchicalDescendants  ...                           NaN
# 9                  hierarchicalDescendants  ...                           NaN
#
#   Outgoing: has part Outgoing: hierarchicalAncestors_uberon  \
# 0                NaN                                    NaN
# 1                NaN                                    NaN
# 2                NaN                                    NaN
# 3                NaN                                    NaN
# 4                NaN                                    NaN
# 5                NaN                                    NaN
# 6                NaN                                    NaN
# 7                NaN                                    NaN
# 8                NaN                                    NaN
# 9                NaN                                    NaN
#
#   Outgoing: hierarchicalChildren_uberon  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
#   Outgoing: hierarchicalDescendants_uberon Outgoing: in taxon  \
# 0                                      NaN                NaN
# 1                                      NaN                NaN
# 2                                      NaN                NaN
# 3                                      NaN                NaN
# 4                                      NaN                NaN
# 5                                      NaN                NaN
# 6                                      NaN                NaN
# 7                                      NaN                NaN
# 8                                      NaN                NaN
# 9                                      NaN                NaN
#
#   Outgoing: overlaps Outgoing: parents Outgoing: part of Synonyms_uberon
# 0                NaN               NaN               NaN             NaN
# 1                NaN               NaN               NaN             NaN
# 2                NaN               NaN               NaN             NaN
# 3                NaN               NaN               NaN             NaN
# 4                NaN               NaN               NaN             NaN
# 5                NaN               NaN               NaN             NaN
# 6                NaN               NaN               NaN             NaN
# 7                NaN               NaN               NaN             NaN
# 8                NaN               NaN               NaN             NaN
# 9                NaN               NaN               NaN             NaN
#
# [10 rows x 49 columns]
#
# Merged CSV saved as 'merged_white_matter.csv'
